# %%
# 画面に「名前を入力してください：」と表示したうえで、キーボードから名前を受付け、変数nameに格納する
name = input("名前を入力してください：")
name
# Out:
# 'tadanori'

# %%
# 画面に「現在の年齢を入力してください：」と表示したうえで、キーボードから年齢を受付け、変数ageに格納する
age = input("現在の年齢を入力してください：")
age
# Out:
# '32'

# %%
# 画面に名前と現在の年齢、来年の年齢を表示する
age = int(age)
age += 1
print(f"私の名前は{name}です。来年で{age}歳になります。")
# Out:
# 私の名前はtadanoriです。来年で33歳になります。
